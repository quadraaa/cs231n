# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Loading CIFAR test batch from cs231n/datasets/cifar-10-batches-py/test_batch...
# python3 detected
# Loaded pickle with datadict
# Loading CIFAR test batch done
# Loading CIFAR10 batch 1 from path cs231n/datasets/cifar-10-batches-py/data_batch_1
# python3 detected
# Loaded pickle with datadict
# Loading CIFAR10 batch 2 from path cs231n/datasets/cifar-10-batches-py/data_batch_2
# python3 detected
# Loaded pickle with datadict
# Loading CIFAR10 batch 3 from path cs231n/datasets/cifar-10-batches-py/data_batch_3
# python3 detected
# Loaded pickle with datadict
# Loading CIFAR10 batch 4 from path cs231n/datasets/cifar-10-batches-py/data_batch_4
# python3 detected
# Loaded pickle with datadict
# Loading CIFAR10 batch 5 from path cs231n/datasets/cifar-10-batches-py/data_batch_5
# python3 detected
# Loaded pickle with datadict
# Xtr concatenated
# Ytr concatenated
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.362931
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 1.032489 analytic: 1.032489, relative error: 8.031088e-08
# numerical: 3.495191 analytic: 3.495191, relative error: 3.680849e-08
# numerical: 0.725265 analytic: 0.725265, relative error: 7.588277e-08
# numerical: 1.612568 analytic: 1.612568, relative error: 3.234059e-08
# numerical: 0.804313 analytic: 0.804313, relative error: 7.980145e-08
# numerical: -0.560430 analytic: -0.560430, relative error: 5.293701e-08
# numerical: -2.883738 analytic: -2.883738, relative error: 5.075918e-09
# numerical: 0.585755 analytic: 0.585755, relative error: 8.453746e-08
# numerical: 0.724717 analytic: 0.724717, relative error: 3.207479e-08
# numerical: 0.910603 analytic: 0.910602, relative error: 6.278606e-08
# numerical: 1.581140 analytic: 1.581140, relative error: 1.020361e-08
# numerical: 1.063445 analytic: 1.063445, relative error: 6.407764e-08
# numerical: 0.830760 analytic: 0.830759, relative error: 6.549750e-08
# numerical: -0.093611 analytic: -0.093611, relative error: 1.522566e-07
# numerical: 1.318691 analytic: 1.318691, relative error: 3.414996e-08
# numerical: 0.450960 analytic: 0.450959, relative error: 1.796387e-07
# numerical: -4.373815 analytic: -4.373815, relative error: 2.463786e-08
# numerical: -0.457666 analytic: -0.457666, relative error: 8.843351e-08
# numerical: 4.296675 analytic: 4.296675, relative error: 1.878538e-08
# numerical: 0.402200 analytic: 0.402200, relative error: 1.306404e-07

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.362931e+00 computed in 0.191187s
# vectorized loss: 2.362931e+00 computed in 0.011678s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = [5e-7, 9e-7, 1e-6]
regularization_strengths = [1e-2, 1e1, 1e2, 1e3, 2.5e4, 5e4, 1e5]

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

pass
for lr in learning_rates:
    for reg in regularization_strengths:
        sftmx = Softmax()
        loss_hist = sftmx.train(X_train, y_train, learning_rate=lr, reg=reg,
                          num_iters=1500, verbose=True)
        y_train_pred = sftmx.predict(X_train)
        y_val_pred = sftmx.predict(X_val)
        accuracy_train = np.mean(y_train == y_train_pred)
        accuracy_val = np.mean(y_val == y_val_pred)
        results[(lr, reg)] = (accuracy_train, accuracy_val)
        if accuracy_val > best_val:
            best_val = accuracy_val
            best_softmax = sftmx

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 5.365192
# iteration 100 / 1500: loss 3.227798
# iteration 200 / 1500: loss 2.478903
# iteration 300 / 1500: loss 2.616012
# iteration 400 / 1500: loss 2.466199
# iteration 500 / 1500: loss 2.466650
# iteration 600 / 1500: loss 2.375533
# iteration 700 / 1500: loss 2.342995
# iteration 800 / 1500: loss 2.297576
# iteration 900 / 1500: loss 2.125860
# iteration 1000 / 1500: loss 2.159814
# iteration 1100 / 1500: loss 2.127391
# iteration 1200 / 1500: loss 2.067666
# iteration 1300 / 1500: loss 2.165487
# iteration 1400 / 1500: loss 2.172474
# iteration 0 / 1500: loss 5.617320
# iteration 100 / 1500: loss 3.486398
# iteration 200 / 1500: loss 3.119371
# iteration 300 / 1500: loss 2.720797
# iteration 400 / 1500: loss 2.845399
# iteration 500 / 1500: loss 2.715830
# iteration 600 / 1500: loss 2.848339
# iteration 700 / 1500: loss 2.448244
# iteration 800 / 1500: loss 2.636138
# iteration 900 / 1500: loss 2.592622
# iteration 1000 / 1500: loss 2.685526
# iteration 1100 / 1500: loss 2.463062
# iteration 1200 / 1500: loss 2.468848
# iteration 1300 / 1500: loss 2.501250
# iteration 1400 / 1500: loss 2.454709
# iteration 0 / 1500: loss 8.091059
# iteration 100 / 1500: loss 5.719386
# iteration 200 / 1500: loss 5.895798
# iteration 300 / 1500: loss 5.344491
# iteration 400 / 1500: loss 5.444283
# iteration 500 / 1500: loss 4.948814
# iteration 600 / 1500: loss 4.982627
# iteration 700 / 1500: loss 5.029976
# iteration 800 / 1500: loss 4.537975
# iteration 900 / 1500: loss 4.740737
# iteration 1000 / 1500: loss 4.409936
# iteration 1100 / 1500: loss 4.587157
# iteration 1200 / 1500: loss 4.557705
# iteration 1300 / 1500: loss 4.289480
# iteration 1400 / 1500: loss 4.173911
# iteration 0 / 1500: loss 37.060104
# iteration 100 / 1500: loss 28.011938
# iteration 200 / 1500: loss 22.637590
# iteration 300 / 1500: loss 18.874590
# iteration 400 / 1500: loss 15.607913
# iteration 500 / 1500: loss 13.098180
# iteration 600 / 1500: loss 10.979547
# iteration 700 / 1500: loss 9.211695
# iteration 800 / 1500: loss 7.946377
# iteration 900 / 1500: loss 6.819439
# iteration 1000 / 1500: loss 5.963702
# iteration 1100 / 1500: loss 5.080692
# iteration 1200 / 1500: loss 4.604999
# iteration 1300 / 1500: loss 3.982454
# iteration 1400 / 1500: loss 3.521779
# iteration 0 / 1500: loss 780.988266
# iteration 100 / 1500: loss 6.943901
# iteration 200 / 1500: loss 2.154279
# iteration 300 / 1500: loss 2.096392
# iteration 400 / 1500: loss 2.083190
# iteration 500 / 1500: loss 2.139767
# iteration 600 / 1500: loss 2.082266
# iteration 700 / 1500: loss 2.110344
# iteration 800 / 1500: loss 2.085251
# iteration 900 / 1500: loss 2.146712
# iteration 1000 / 1500: loss 2.088596
# iteration 1100 / 1500: loss 2.130243
# iteration 1200 / 1500: loss 2.089194
# iteration 1300 / 1500: loss 2.111803
# iteration 1400 / 1500: loss 2.058871
# iteration 0 / 1500: loss 1550.515082
# iteration 100 / 1500: loss 2.199198
# iteration 200 / 1500: loss 2.132680
# iteration 300 / 1500: loss 2.156124
# iteration 400 / 1500: loss 2.211185
# iteration 500 / 1500: loss 2.127090
# iteration 600 / 1500: loss 2.152080
# iteration 700 / 1500: loss 2.087504
# iteration 800 / 1500: loss 2.183195
# iteration 900 / 1500: loss 2.108451
# iteration 1000 / 1500: loss 2.174151
# iteration 1100 / 1500: loss 2.143153
# iteration 1200 / 1500: loss 2.141544
# iteration 1300 / 1500: loss 2.105152
# iteration 1400 / 1500: loss 2.144150
# iteration 0 / 1500: loss 3081.312179
# iteration 100 / 1500: loss 2.232774
# iteration 200 / 1500: loss 2.226302
# iteration 300 / 1500: loss 2.203603
# iteration 400 / 1500: loss 2.198835
# iteration 500 / 1500: loss 2.195424
# iteration 600 / 1500: loss 2.172123
# iteration 700 / 1500: loss 2.169870
# iteration 800 / 1500: loss 2.213487
# iteration 900 / 1500: loss 2.201767
# iteration 1000 / 1500: loss 2.211472
# iteration 1100 / 1500: loss 2.235812
# iteration 1200 / 1500: loss 2.176724
# iteration 1300 / 1500: loss 2.176458
# iteration 1400 / 1500: loss 2.172710
# iteration 0 / 1500: loss 5.544280
# iteration 100 / 1500: loss 2.933819
# iteration 200 / 1500: loss 2.555808
# iteration 300 / 1500: loss 2.409256
# iteration 400 / 1500: loss 2.168902
# iteration 500 / 1500: loss 2.343117
# iteration 600 / 1500: loss 2.071874
# iteration 700 / 1500: loss 2.083644
# iteration 800 / 1500: loss 2.074474
# iteration 900 / 1500: loss 1.984679
# iteration 1000 / 1500: loss 1.944348
# iteration 1100 / 1500: loss 1.906338
# iteration 1200 / 1500: loss 2.133480
# iteration 1300 / 1500: loss 2.030029
# iteration 1400 / 1500: loss 1.974094
# iteration 0 / 1500: loss 5.936418
# iteration 100 / 1500: loss 3.266164
# iteration 200 / 1500: loss 2.702122
# iteration 300 / 1500: loss 2.753637
# iteration 400 / 1500: loss 2.444405
# iteration 500 / 1500: loss 2.539291
# iteration 600 / 1500: loss 2.486122
# iteration 700 / 1500: loss 2.479466
# iteration 800 / 1500: loss 2.412971
# iteration 900 / 1500: loss 2.441991
# iteration 1000 / 1500: loss 2.389347
# iteration 1100 / 1500: loss 2.462607
# iteration 1200 / 1500: loss 2.170418
# iteration 1300 / 1500: loss 2.146156
# iteration 1400 / 1500: loss 2.163381
# iteration 0 / 1500: loss 9.086780
# iteration 100 / 1500: loss 5.530596
# iteration 200 / 1500: loss 5.274959
# iteration 300 / 1500: loss 5.143584
# iteration 400 / 1500: loss 4.936537
# iteration 500 / 1500: loss 4.561633
# iteration 600 / 1500: loss 4.556840
# iteration 700 / 1500: loss 4.447333
# iteration 800 / 1500: loss 4.379458
# iteration 900 / 1500: loss 4.297481
# iteration 1000 / 1500: loss 4.118437
# iteration 1100 / 1500: loss 3.899330
# iteration 1200 / 1500: loss 3.774265
# iteration 1300 / 1500: loss 3.596168
# iteration 1400 / 1500: loss 3.623269
# iteration 0 / 1500: loss 37.353407
# iteration 100 / 1500: loss 23.983503
# iteration 200 / 1500: loss 17.083511
# iteration 300 / 1500: loss 12.114785
# iteration 400 / 1500: loss 9.108716
# iteration 500 / 1500: loss 6.816245
# iteration 600 / 1500: loss 5.221264
# iteration 700 / 1500: loss 4.233655
# iteration 800 / 1500: loss 3.518626
# iteration 900 / 1500: loss 2.938008
# iteration 1000 / 1500: loss 2.660063
# iteration 1100 / 1500: loss 2.365465
# iteration 1200 / 1500: loss 2.200075
# iteration 1300 / 1500: loss 2.063435
# iteration 1400 / 1500: loss 1.991703
# iteration 0 / 1500: loss 775.574085
# iteration 100 / 1500: loss 2.164057
# iteration 200 / 1500: loss 2.091968
# iteration 300 / 1500: loss 2.104596
# iteration 400 / 1500: loss 2.097622
# iteration 500 / 1500: loss 2.110366
# iteration 600 / 1500: loss 2.081556
# iteration 700 / 1500: loss 2.131094
# iteration 800 / 1500: loss 2.061345
# iteration 900 / 1500: loss 2.117517
# iteration 1000 / 1500: loss 2.145080
# iteration 1100 / 1500: loss 2.084589
# iteration 1200 / 1500: loss 2.077367
# iteration 1300 / 1500: loss 2.069211
# iteration 1400 / 1500: loss 2.124897
# iteration 0 / 1500: loss 1558.456193
# iteration 100 / 1500: loss 2.191094
# iteration 200 / 1500: loss 2.088834
# iteration 300 / 1500: loss 2.141343
# iteration 400 / 1500: loss 2.165696
# iteration 500 / 1500: loss 2.188652
# iteration 600 / 1500: loss 2.194387
# iteration 700 / 1500: loss 2.138763
# iteration 800 / 1500: loss 2.156669
# iteration 900 / 1500: loss 2.186772
# iteration 1000 / 1500: loss 2.125618
# iteration 1100 / 1500: loss 2.119717
# iteration 1200 / 1500: loss 2.116498
# iteration 1300 / 1500: loss 2.211314
# iteration 1400 / 1500: loss 2.225457
# iteration 0 / 1500: loss 3060.616925
# iteration 100 / 1500: loss 2.176999
# iteration 200 / 1500: loss 2.253697
# iteration 300 / 1500: loss 2.203808
# iteration 400 / 1500: loss 2.201802
# iteration 500 / 1500: loss 2.191900
# iteration 600 / 1500: loss 2.168906
# iteration 700 / 1500: loss 2.231851
# iteration 800 / 1500: loss 2.206142
# iteration 900 / 1500: loss 2.175160
# iteration 1000 / 1500: loss 2.210747
# iteration 1100 / 1500: loss 2.205177
# iteration 1200 / 1500: loss 2.207931
# iteration 1300 / 1500: loss 2.209264
# iteration 1400 / 1500: loss 2.227649
# iteration 0 / 1500: loss 6.410780
# iteration 100 / 1500: loss 2.780423
# iteration 200 / 1500: loss 2.550574
# iteration 300 / 1500: loss 2.268420
# iteration 400 / 1500: loss 2.366919
# iteration 500 / 1500: loss 2.440935
# iteration 600 / 1500: loss 2.092250
# iteration 700 / 1500: loss 1.981398
# iteration 800 / 1500: loss 2.205684
# iteration 900 / 1500: loss 1.922331
# iteration 1000 / 1500: loss 1.980173
# iteration 1100 / 1500: loss 1.808489
# iteration 1200 / 1500: loss 2.096981
# iteration 1300 / 1500: loss 2.087214
# iteration 1400 / 1500: loss 1.942791
# iteration 0 / 1500: loss 6.444213
# iteration 100 / 1500: loss 2.879517
# iteration 200 / 1500: loss 2.719298
# iteration 300 / 1500: loss 2.627581
# iteration 400 / 1500: loss 2.465357
# iteration 500 / 1500: loss 2.626955
# iteration 600 / 1500: loss 2.433971
# iteration 700 / 1500: loss 2.304670
# iteration 800 / 1500: loss 2.309011
# iteration 900 / 1500: loss 2.477944
# iteration 1000 / 1500: loss 2.352393
# iteration 1100 / 1500: loss 2.366215
# iteration 1200 / 1500: loss 2.366480
# iteration 1300 / 1500: loss 2.005477
# iteration 1400 / 1500: loss 2.283864
# iteration 0 / 1500: loss 8.881987
# iteration 100 / 1500: loss 5.778199
# iteration 200 / 1500: loss 5.150252
# iteration 300 / 1500: loss 5.102349
# iteration 400 / 1500: loss 4.773367
# iteration 500 / 1500: loss 4.507277
# iteration 600 / 1500: loss 4.381876
# iteration 700 / 1500: loss 4.100087
# iteration 800 / 1500: loss 4.186753
# iteration 900 / 1500: loss 3.969878
# iteration 1000 / 1500: loss 3.917191
# iteration 1100 / 1500: loss 3.751790
# iteration 1200 / 1500: loss 3.824029
# iteration 1300 / 1500: loss 3.517020
# iteration 1400 / 1500: loss 3.465197
# iteration 0 / 1500: loss 36.581726
# iteration 100 / 1500: loss 22.683187
# iteration 200 / 1500: loss 15.599335
# iteration 300 / 1500: loss 11.001619
# iteration 400 / 1500: loss 7.843886
# iteration 500 / 1500: loss 5.927993
# iteration 600 / 1500: loss 4.382233
# iteration 700 / 1500: loss 3.524552
# iteration 800 / 1500: loss 3.029981
# iteration 900 / 1500: loss 2.711727
# iteration 1000 / 1500: loss 2.316044
# iteration 1100 / 1500: loss 2.193480
# iteration 1200 / 1500: loss 2.012204
# iteration 1300 / 1500: loss 1.936982
# iteration 1400 / 1500: loss 1.947576
# iteration 0 / 1500: loss 789.716028
# iteration 100 / 1500: loss 2.110672
# iteration 200 / 1500: loss 2.056127
# iteration 300 / 1500: loss 2.106478
# iteration 400 / 1500: loss 2.124246
# iteration 500 / 1500: loss 2.077270
# iteration 600 / 1500: loss 2.045670
# iteration 700 / 1500: loss 2.097504
# iteration 800 / 1500: loss 2.087680
# iteration 900 / 1500: loss 2.093808
# iteration 1000 / 1500: loss 2.103004
# iteration 1100 / 1500: loss 2.109911
# iteration 1200 / 1500: loss 2.095529
# iteration 1300 / 1500: loss 2.082535
# iteration 1400 / 1500: loss 2.085733
# iteration 0 / 1500: loss 1555.403774
# iteration 100 / 1500: loss 2.106332
# iteration 200 / 1500: loss 2.159468
# iteration 300 / 1500: loss 2.141726
# iteration 400 / 1500: loss 2.140932
# iteration 500 / 1500: loss 2.151112
# iteration 600 / 1500: loss 2.173384
# iteration 700 / 1500: loss 2.157661
# iteration 800 / 1500: loss 2.166542
# iteration 900 / 1500: loss 2.189852
# iteration 1000 / 1500: loss 2.124377
# iteration 1100 / 1500: loss 2.131732
# iteration 1200 / 1500: loss 2.156400
# iteration 1300 / 1500: loss 2.144903
# iteration 1400 / 1500: loss 2.159775
# iteration 0 / 1500: loss 3074.303311
# iteration 100 / 1500: loss 2.239025
# iteration 200 / 1500: loss 2.223883
# iteration 300 / 1500: loss 2.190908
# iteration 400 / 1500: loss 2.249105
# iteration 500 / 1500: loss 2.186830
# iteration 600 / 1500: loss 2.247211
# iteration 700 / 1500: loss 2.216322
# iteration 800 / 1500: loss 2.214032
# iteration 900 / 1500: loss 2.202188
# iteration 1000 / 1500: loss 2.206121
# iteration 1100 / 1500: loss 2.217409
# iteration 1200 / 1500: loss 2.233109
# iteration 1300 / 1500: loss 2.203157
# iteration 1400 / 1500: loss 2.210147
# lr 5.000000e-07 reg 1.000000e-02 train accuracy: 0.320163 val accuracy: 0.324000
# lr 5.000000e-07 reg 1.000000e+01 train accuracy: 0.319449 val accuracy: 0.316000
# lr 5.000000e-07 reg 1.000000e+02 train accuracy: 0.327918 val accuracy: 0.310000
# lr 5.000000e-07 reg 1.000000e+03 train accuracy: 0.383245 val accuracy: 0.387000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.323449 val accuracy: 0.332000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.306796 val accuracy: 0.324000
# lr 5.000000e-07 reg 1.000000e+05 train accuracy: 0.268510 val accuracy: 0.279000
# lr 9.000000e-07 reg 1.000000e-02 train accuracy: 0.343469 val accuracy: 0.341000
# lr 9.000000e-07 reg 1.000000e+01 train accuracy: 0.347837 val accuracy: 0.330000
# lr 9.000000e-07 reg 1.000000e+02 train accuracy: 0.354857 val accuracy: 0.354000
# lr 9.000000e-07 reg 1.000000e+03 train accuracy: 0.400265 val accuracy: 0.410000
# lr 9.000000e-07 reg 2.500000e+04 train accuracy: 0.320347 val accuracy: 0.325000
# lr 9.000000e-07 reg 5.000000e+04 train accuracy: 0.279061 val accuracy: 0.305000
# lr 9.000000e-07 reg 1.000000e+05 train accuracy: 0.289306 val accuracy: 0.293000
# lr 1.000000e-06 reg 1.000000e-02 train accuracy: 0.348429 val accuracy: 0.322000
# lr 1.000000e-06 reg 1.000000e+01 train accuracy: 0.348388 val accuracy: 0.341000
# lr 1.000000e-06 reg 1.000000e+02 train accuracy: 0.365837 val accuracy: 0.357000
# lr 1.000000e-06 reg 1.000000e+03 train accuracy: 0.398776 val accuracy: 0.402000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.314490 val accuracy: 0.326000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.302347 val accuracy: 0.301000
# lr 1.000000e-06 reg 1.000000e+05 train accuracy: 0.268816 val accuracy: 0.289000
# best validation accuracy achieved during cross-validation: 0.410000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.383000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
